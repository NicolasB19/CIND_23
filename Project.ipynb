# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasB19/CinD_23/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **First Part**
#
# Picth
#
# Format - .ipynb
#
# Contents:
#
# ***1. Variable:***
# # **Road freight transport**
#
#   **1.1. Name and description.**
#
# -  The influence of road freight transportation throughout the country and kilometers traveled.
#
#   **1.2. Period or dates. Frequency. Individuals.**
#
# *  Monthly periods of kilometers driven.
#
# *  The individuals chosen were road freight forwarders because it is important to understand the overland transportation and logistics sector.
#
#   **1.3. Sources (with links).**
#
#
# *  [Datos](https://https://www.datos.gov.co/Transporte/Registro-Nacional-de-Despachos-de-Carga-por-Carret/vn9u-yhwq/)
#
# *  [Min. transporte](https://https://plc.mintransporte.gov.co//)
#
#
# ***2. Goal of the DV***
#
# *  The fundamental purpose was to create a space capable of implementing mechanisms for interpreting the reality of the transporters, promoting their interests and responding effectively to their needs.
#
#     **2.1. Story.**
#
# *  The consolidation of industrial and commercial development in the transport business in Colombia
#
# *  It is important to investigate the variable of how many kilometers truck drivers drive monthly throughout the country.
#
#     **2.2. Audience.**
#
# * This work is aimed mainly at the transportation sector, the commercial industry and drivers who travel the country by land.
#
#     2.3. Justify the DV type.
#
# * The style to be used will be by means of images, tables and statistical graphs that represent the transport sector.
#
#
# ***3. Examples***
#
#   **3.1. First point or Origin**
#
#   | Fecha | Municipio | Km |
#   |-------|-------------|-----|
#   |2022-01 | Bogotá | 61.916 |
#   |2022-01 | Buenaventura | 41.891 |
#   | 2022-01 | Barranquilla | 36.891 |
#   | 2022-01 | Cartagena | 32.752 |
#   | 2022-01 | Medellín | 24.173 |
#
#   **3.2. Second point or Destination**
#
#
#   | Fecha | Municipio | Km |
#   |-------|-------------|-----|
#   |2022-01 | Bogotá | 71.586 |
#   |2022-01 | Buenaventura | 36.695 |
#   | 2022-01 | Barranquilla | 36.891 |
#   | 2022-01 | Cartagena | 31.559 |
#   | 2022-01 | Medellín | 21.876 |
#
#   **3.3. Example Image**

# %% [markdown]
# ![National Transport.jpg](data:image/jpeg;base64,...)
